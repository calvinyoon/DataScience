# %%
import pandas as pd
data_frame = pd.read_csv('fifa19_data.csv')
data_frame.shape
# Out:
# (18207, 90)

# %%
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18206.000000  18206.000000  18207.000000
# mean    9103.000000  214298.338606     25.122048     66.237449     71.307299
# std     5256.052511   29965.244204      4.670022      6.907059      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#           Weak Foot   Skill Moves     Finishing  HeadingAccuracy  \
# count  18159.000000  18159.000000  18159.000000     18159.000000
# mean       2.944215      2.362685     45.560273        52.282670
# std        0.664361      0.756561     19.519091        17.393362
# min        1.000000      1.000000      2.000000         4.000000
# 25%        3.000000      2.000000     30.000000        44.000000
# 50%        3.000000      2.000000     49.000000        56.000000
# 75%        3.000000      3.000000     62.000000        64.000000
# max        5.000000      5.000000     95.000000        94.000000
#
#        ShortPassing  ...     Penalties     Composure       Marking  \
# count  18159.000000  ...  18159.000000  18159.000000  18159.000000
# mean      58.676579  ...     48.561760     58.630762     47.283496
# std       14.706456  ...     15.704481     11.454790     19.900403
# min        7.000000  ...      5.000000      3.000000      3.000000
# 25%       54.000000  ...     39.000000     51.000000     30.000000
# 50%       62.000000  ...     49.000000     60.000000     53.000000
# 75%       68.000000  ...     60.000000     67.000000     64.000000
# max       93.000000  ...     92.000000     96.000000     94.000000
#
#        StandingTackle  SlidingTackle      GKDiving    GKHandling  \
# count    18159.000000   18159.000000  18159.000000  18159.000000
# mean        47.701911      45.663858     16.664244     16.391707
# std         21.663252      21.290492     17.733472     16.908588
# min          2.000000       3.000000      1.000000      1.000000
# 25%         27.000000      24.000000      8.000000      8.000000
# 50%         55.000000      52.000000     11.000000     11.000000
# 75%         66.000000      64.000000     14.000000     14.000000
# max         93.000000      91.000000     90.000000     92.000000
#
#           GKKicking  GKPositioning    GKReflexes
# count  18159.000000   18159.000000  18159.000000
# mean      16.230409      16.390881     16.708519
# std       16.501483      17.035594     17.956907
# min        1.000000       1.000000      1.000000
# 25%        8.000000       8.000000      8.000000
# 50%       11.000000      11.000000     11.000000
# 75%       14.000000      14.000000     14.000000
# max       91.000000      90.000000     94.000000
#
# [8 rows x 40 columns]

# %%
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 8.0, '€226.5M', nan],
#        [1, 20801, 'Cristiano Ronaldo', ..., 11.0, '€127.1M', nan],
#        [2, 190871, 'Neymar Jr', ..., 11.0, '€228.1M', nan],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 13.0, '€165K', nan],
#        [18205, 246268, 'D. Walker-Rice', ..., 9.0, '€143K', nan],
#        [18206, 246269, 'G. Nugent', ..., 9.0, '€165K', nan]], dtype=object)

# %%
data_frame[data_frame["Age"]>40].head()
# Out:
#        Unnamed: 0      ID         Name   Age  \
# 1120         1120  156092    J. Villar  41.0
# 4228         4228    3665     B. Nivet  41.0
# 4741         4741  140029     O. Pérez  45.0
# 7225         7225  142998     C. Muñoz  41.0
# 10545       10545  140183  S. Narazaki  42.0
#
#                                                 Photo Nationality  \
# 1120   https://cdn.sofifa.org/players/4/19/156092.png    Paraguay
# 4228     https://cdn.sofifa.org/players/4/19/3665.png      France
# 4741   https://cdn.sofifa.org/players/4/19/140029.png      Mexico
# 7225   https://cdn.sofifa.org/players/4/19/142998.png   Argentina
# 10545  https://cdn.sofifa.org/players/4/19/140183.png       Japan
#
#                                        Flag  Overall  Potential  \
# 1120    https://cdn.sofifa.org/flags/58.png     77.0         77
# 4228    https://cdn.sofifa.org/flags/18.png     71.0         71
# 4741    https://cdn.sofifa.org/flags/83.png     71.0         71
# 7225    https://cdn.sofifa.org/flags/52.png     68.0         68
# 10545  https://cdn.sofifa.org/flags/163.png     65.0         65
#
#                                Club  ... Marking StandingTackle SlidingTackle  \
# 1120                            NaN  ...    13.0           13.0          14.0
# 4228                   ESTAC Troyes  ...    58.0           56.0          43.0
# 4741                        Pachuca  ...    23.0           12.0          11.0
# 7225   CD Universidad de Concepción  ...    18.0           14.0          19.0
# 10545                Nagoya Grampus  ...    27.0           24.0          22.0
#
#       GKDiving GKHandling GKKicking  GKPositioning  GKReflexes Release Clause  \
# 1120      75.0       75.0      74.0           78.0        77.0            NaN
# 4228      11.0        7.0       8.0           14.0         7.0            NaN
# 4741      70.0       64.0      65.0           73.0        74.0          €272K
# 7225      67.0       65.0      68.0           71.0        68.0           €84K
# 10545     64.0       63.0      62.0           67.0        63.0           €50K
#
#       Unnamed: 89
# 1120          NaN
# 4228          NaN
# 4741          NaN
# 7225          NaN
# 10545         NaN
#
# [5 rows x 90 columns]

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace('[\€]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#               Name        Wage        Value   difference
# 2        Neymar Jr    290000.0  118500000.0  118210000.0
# 0         L. Messi    565000.0  110500000.0  109935000.0
# 4     K. De Bruyne    355000.0  102000000.0  101645000.0
# 5        E. Hazard    340000.0   93000000.0   92660000.0
# 15       P. Dybala    205000.0   89000000.0   88795000.0
# ...            ...         ...          ...          ...
# 5881     Tang Miao    875000.0          0.0    -875000.0
# 2590      D. Toši?   2300000.0          0.0   -2300000.0
# 1758   Júnior Urso   5000000.0          0.0   -5000000.0
# 2262     Renatinho   5500000.0          0.0   -5500000.0
# 461      E. Zahavi  14500000.0          0.0  -14500000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name"),
])

p = figure(title="Soccer 2019", x_axis_label='Wage', y_axis_label='Value', width=700, height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
